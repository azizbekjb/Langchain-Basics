# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent, AgentState
from langchain.agents.middleware import SummarizationMiddleware, before_agent, after_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.messages import HumanMessage, AIMessage, ToolMessage, RemoveMessage
from langchain.tools import ToolRuntime
from langgraph.runtime import Runtime
from pprint import pprint

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Summarize messages

# %%
model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai")

# %%
agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=model,
            trigger=("tokens", 100),
            keep=("messages", 1)
        )
    ]
)

# %%
response = agent.invoke(
    {
        "messages":[
            HumanMessage(content="What is the capital of the moon?"),
            AIMessage(content="The capital of the moon is Lunapolis."),
            HumanMessage(content="What is the weather in Lunapolis?"),
            AIMessage(content="Skies are clear, with a high of 120C and a low of -100C."),
            HumanMessage(content="How many cheese miners live in Lunapolis?"),
            AIMessage(content="There are 100,000 cheese miners living in Lunapolis."),
            HumanMessage(content="Do you think the cheese miners' union will strike?"),
            AIMessage(content="Yes, because they are unhappy with the new president."),
            HumanMessage(content="If you were Lunapolis' new president how would you respond to the cheese miners' union?"),
        ]
    },
    {"configurable": {"thread_id": "1"}}
)

pprint(response)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:3040, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3039 try:
# -> 3040     response: GenerateContentResponse = self.client.models.generate_content(
#    3041         **request,
#    3042     )
#    3043 except ClientError as e:
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/google/genai/models.py:5203, in Models.generate_content(self, model, contents, config)
#    5202 i += 1
# -> 5203 response = self._generate_content(
#    5204     model=model, contents=contents, config=parsed_config
#    5205 )
#    5207 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/google/genai/models.py:3985, in Models._generate_content(self, model, contents, config)
#    3983 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3985 response = self._api_client.request(
#    3986     'post', path, request_dict, http_options
#    3987 )
#    3989 if config is not None and getattr(
#    3990     config, 'should_return_http_response', None
#    3991 ):
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/google/genai/_api_client.py:1388, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1385 http_request = self._build_request(
#    1386     http_method, path, request_dict, http_options
#    1387 )
# -> 1388 response = self._request(http_request, http_options, stream=False)
#    1389 response_body = (
#    1390     response.response_stream[0] if response.response_stream else ''
#    1391 )
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/google/genai/_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1221     retry = tenacity.Retrying(**retry_kwargs)
# -> 1222     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1224 return self._retry(self._request_once, http_request, stream)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/google/genai/_api_client.py:1201, in BaseApiClient._request_once(self, http_request, stream)
#    1194 response = self._httpx_client.request(
#    1195     method=http_request.method,
#    1196     url=http_request.url,
#    (...)   1199     timeout=http_request.timeout,
#    1200 )
# -> 1201 errors.APIError.raise_for_response(response)
#    1202 return HttpResponse(
#    1203     response.headers, response if stream else [response.text]
#    1204 )
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/google/genai/errors.py:121, in APIError.raise_for_response(cls, response)
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/google/genai/errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 20.154542142s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = agent.invoke(
#       2     {
#       3         "messages":[
#       4             HumanMessage(content="What is the capital of the moon?"),
#       5             AIMessage(content="The capital of the moon is Lunapolis."),
#       6             HumanMessage(content="What is the weather in Lunapolis?"),
#       7             AIMessage(content="Skies are clear, with a high of 120C and a low of -100C."),
#       8             HumanMessage(content="How many cheese miners live in Lunapolis?"),
#       9             AIMessage(content="There are 100,000 cheese miners living in Lunapolis."),
#      10             HumanMessage(content="Do you think the cheese miners' union will strike?"),
#      11             AIMessage(content="Yes, because they are unhappy with the new president."),
#      12             HumanMessage(content="If you were Lunapolis' new president how would you respond to the cheese miners' union?"),
#      13         ]
#      14     },
#      15     {"configurable": {"thread_id": "1"}}
#      16 )
#      18 pprint(response)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain/agents/factory.py:1131, in create_agent.<locals>.model_node(state, runtime)
#    1118 request = ModelRequest(
#    1119     model=model,
#    1120     tools=default_tools,
#    (...)   1126     runtime=runtime,
#    1127 )
#    1129 if wrap_model_call_handler is None:
#    1130     # No handlers - execute directly
# -> 1131     response = _execute_model_sync(request)
#    1132 else:
#    1133     # Call composed handler with base handler
#    1134     response = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain/agents/factory.py:1102, in create_agent.<locals>._execute_model_sync(request)
#    1099 if request.system_message:
#    1100     messages = [request.system_message, *messages]
# -> 1102 output = model_.invoke(messages)
#    1103 if name:
#    1104     output.name = name
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5557, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5550 @override
#    5551 def invoke(
#    5552     self,
#    (...)   5555     **kwargs: Any | None,
#    5556 ) -> Output:
# -> 5557     return self.bound.invoke(
#    5558         input,
#    5559         self._merge_configs(config),
#    5560         **{**self.kwargs, **kwargs},
#    5561     )
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:2529, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2526         msg = "Tools are already defined.code_execution tool can't be defined"
#    2527         raise ValueError(msg)
# -> 2529 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1121, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1112 @override
#    1113 def generate_prompt(
#    1114     self,
#    (...)   1118     **kwargs: Any,
#    1119 ) -> LLMResult:
#    1120     prompt_messages = [p.to_messages() for p in prompts]
# -> 1121     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:931, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     928 for i, m in enumerate(input_messages):
#     929     try:
#     930         results.append(
# --> 931             self._generate_with_cache(
#     932                 m,
#     933                 stop=stop,
#     934                 run_manager=run_managers[i] if run_managers else None,
#     935                 **kwargs,
#     936             )
#     937         )
#     938     except BaseException as e:
#     939         if run_managers:
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1225, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1223     result = generate_from_stream(iter(chunks))
#    1224 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1225     result = self._generate(
#    1226         messages, stop=stop, run_manager=run_manager, **kwargs
#    1227     )
#    1228 else:
#    1229     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:3044, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3040     response: GenerateContentResponse = self.client.models.generate_content(
#    3041         **request,
#    3042     )
#    3043 except ClientError as e:
# -> 3044     _handle_client_error(e, request)
#    3046 return _response_to_result(response)
#
# File ~/Python/Projects/Laws-Downloader/venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 20.154542142s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
# During task with name 'model' and id '8ad96d3d-199d-a6fe-cccb-76b3a7ee2097'

# %%
print(response["messages"][-1].content)
# Out:
# As Lunapolis' new president, facing an expected strike from 100,000 vital cheese miners due to dissatisfaction with my new administration, my response would be multi-faceted, prioritizing immediate de-escalation, understanding, and collaboration.
#
# Here's my plan:
#
# 1.  **Immediate Call for Dialogue (Before the Strike):**
#     *   **Public Statement:** I would issue a public statement acknowledging the union's concerns, emphasizing the critical role cheese miners play in Lunapolis' economy and well-being. I'd stress that their voice is heard and valued.
#     *   **Urgent Meeting Invitation:** Simultaneously, I would extend an immediate, personal invitation to the union's leadership for a direct meeting with me and key members of my administration, even before any strike officially begins. The goal is to prevent the strike from ever happening by opening lines of communication.
#
# 2.  **Listen and Understand:**
#     *   **Active Listening:** In the meeting, my primary role would be to listen intently. I would ask open-ended questions to fully understand the specific grievances. Is it about:
#         *   Wages or benefits?
#         *   Working conditions (especially given the extreme temperatures)?
#         *   Job security?
#         *   Lack of consultation on new policies?
#         *   A perceived lack of respect or recognition from the new administration?
#         *   Long-standing issues that have festered and are now being directed at the new president?
#     *   **No Immediate Promises:** I would avoid making any snap decisions or promises during this initial listening phase, but assure them their concerns are being taken seriously.
#
# 3.  **Formulate a Strategic Response:**
#     *   **Categorize Demands:** Based on their input, I would categorize their demands into immediate, short-term, and long-term issues.
#     *   **Feasible & Immediate Actions:** If there are "low-hanging fruit" issues that can be addressed quickly and meaningfully (e.g., improving a specific safety protocol, clearer communication channels for grievances), I would commit to implementing them promptly to build trust.
#     *   **Negotiable Points:** For core issues like wages, benefits, or working hours, I would come to the table with a prepared position but also flexibility for negotiation. I would use data to demonstrate financial realities but also be open to creative solutions (e.g., performance bonuses tied to cheese yield, improved housing options, specialized equipment for extreme conditions).
#     *   **Long-term & Structural Changes:** If dissatisfaction stems from deeper systemic issues, I would propose forming a joint task force comprising government officials, union representatives, and independent experts to study and propose solutions for the long term. This demonstrates a commitment beyond the immediate crisis.
#     *   **Transparency:** Be honest about what is possible and what isn't, explaining the rationale behind decisions.
#
# 4.  **Emphasize Shared Prosperity:**
#     *   I would consistently frame the discussion around the shared prosperity of Lunapolis. A thriving cheese mining industry benefits everyone. A strong, well-compensated workforce is more productive and leads to greater overall stability.
#     *   I might propose initiatives that link the miners' success directly to the city's success, perhaps a share in increased cheese exports or a city-wide recognition program for their contributions.
#
# 5.  **Establish Ongoing Communication:**
#     *   Beyond resolving the immediate threat of a strike, I would commit to establishing regular, structured communication channels between my office and the union leadership. This could involve quarterly meetings, a dedicated liaison, or involvement in policy discussions that directly impact their work. This is crucial for preventing future crises and building a lasting, respectful relationship.
#
# My overall tone would be one of empathy, pragmatism, and a genuine desire to find common ground. I would aim to turn this potential crisis into an opportunity to solidify trust and build a stronger, more collaborative relationship with Lunapolis' essential cheese miners.

# %%
from typing import Any

@before_agent
def trim_messages(state: AgentState, runtime: Runtime) -> dict[str, Any]:
    """Remove all the tool messages from the state"""

    messages = state['messages']
    tool_messages = [m for m in messages if isinstance(m, ToolMessage)]

    return {"messages": [RemoveMessage(id=m.id,) for m in tool_messages]}

# %%
agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),
    middleware=[trim_messages]
)

# %%
response = agent.invoke(
    {"messages": [
        HumanMessage(content="My device won't turn on. What should I do?"),
        ToolMessage(content="blorp-x7 initiating diagnostic ping…", tool_call_id="1"),
        AIMessage(content="Is the device plugged in and turned on?"),
        HumanMessage(content="Yes, it's plugged in and turned on."),
        ToolMessage(content="temp=42C voltage=2.9v … greeble complete.", tool_call_id="2"),
        AIMessage(content="Is the device showing any lights or indicators?"),
        HumanMessage(content="What's the temperature of the device?")
        ]},
    {"configurable": {"thread_id": "2"}}
)

pprint(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = agent.invoke(
#       2     {"messages": [
#       3         HumanMessage(content="My device won't turn on. What should I do?"),
#       4         ToolMessage(content="blorp-x7 initiating diagnostic ping…", tool_call_id="1"),
#       5         AIMessage(content="Is the device plugged in and turned on?"),
#       6         HumanMessage(content="Yes, it's plugged in and turned on."),
#       7         ToolMessage(content="temp=42C voltage=2.9v … greeble complete.", tool_call_id="2"),
#       8         AIMessage(content="Is the device showing any lights or indicators?"),
#       9         HumanMessage(content="What's the temperature of the device?")
#      10         ]},
#      11     {"configurable": {"thread_id": "2"}}
#      12 )
#      14 pprint(response)
#
# NameError: name 'agent' is not defined

# %%
print(response["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(response["messages"][-1].content)
#
# NameError: name 'response' is not defined
