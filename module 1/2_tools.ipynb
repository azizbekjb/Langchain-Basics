# %%
from dotenv import load_dotenv
from langchain.tools import tool
from langchain.messages import HumanMessage
from langchain.agents import create_agent
from pprint import pprint

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# # Tool difinition

# %%
@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x**0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x**0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x**0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# # Adding to agents

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai")
agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke({"messages":[question]})
print(response["messages"][-1].content)
# Out:
# The square root of 467 is 21.61018278497431.

# %%
pprint(response["messages"])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='ca0846f9-fc51-4262-b091-382cea410a94'),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'square_root', 'arguments': '{"x": 467}'}, '__gemini_function_call_thought_signatures__': {'3dcf7e82-c439-4d4c-a104-b0cc885267db': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b8c5b-b110-7681-b456-5b6f342d6119-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': '3dcf7e82-c439-4d4c-a104-b0cc885267db', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 71, 'output_tokens': 79, 'total_tokens': 150, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 62}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='5d0655d8-9629-46fb-89df-8d0c4ca60bdb', tool_call_id='3dcf7e82-c439-4d4c-a104-b0cc885267db'),
#  AIMessage(content='The square root of 467 is 21.61018278497431.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b8c5b-b658-77a0-a216-c2bdae26ba1f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 119, 'output_tokens': 28, 'total_tokens': 147, 'input_token_details': {'cache_read': 0}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': '3dcf7e82-c439-4d4c-a104-b0cc885267db', 'type': 'tool_call'}]
