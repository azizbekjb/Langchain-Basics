# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.messages import HumanMessage
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

# %%
load_dotenv()
# Out:
# True

# %%
tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """
You are a personal chef. The user will give you a list of ingredients they have left over their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return reciepe suggestion and eventualy the recipe instructions to the user, if requested.

"""

# %%
model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai")
agent = create_agent(
    model = model,
    tools=[web_search],
    system_prompt = system_prompt,
    checkpointer = InMemorySaver()
)

# %%
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover checken and rice. What can I make?")]},
    config
)

print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': "You can make several delicious dishes with leftover chicken and rice! Here are a few suggestions:\n\n*   Easy Chicken and Rice\n*   One-Pot Chicken and Rice\n*   Marry Me Chicken and Rice\n*   30 Minute One Pan Chicken and Rice\n*   My Mom's One-Pot Chicken and Rice\n\nWould you like the instructions for any of these recipes?", 'extras': {'signature': '...'}}]

# %%
from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover checken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='6c1401c8-f08b-40c8-b47e-b849fbc926c6'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with chicken and rice"}'}, '__gemini_function_call_thought_signatures__': {'6c30f5e5-a079-4737-b97d-6ef741a9a251': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bc77c-97c4-7f12-b471-667f937eaa64-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with chicken and rice'}, 'id': '6c30f5e5-a079-4737-b97d-6ef741a9a251', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 117, 'output_tokens': 61, 'total_tokens': 178, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 42}}),
#               ToolMessage(content='{"query": "recipes with chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.acouplecooks.com/chicken-and-rice-recipe/", "title": "Easy Chicken and Rice - Dinner Recipes - A Couple Cooks", "content": "This one pot chicken and rice recipe is an easy dinner with tender chicken thighs and fluffy rice, topped with a fresh lemon parsley", "score": 0.9999403, "raw_content": null}, {"url": "https://iowagirleats.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Family Favorite Recipe - Iowa Girl Eats", "content": "Part risotto (without all the stirring) and part soup, this creamy chicken and rice recipe is simple, comforting, and made entirely in one pot with fridge and pantry staples. **Step 4:** Season **chicken breasts** that have been chopped into bite-sized pieces with **seasoned salt** and **pepper** then add to the soup pot and continue to simmer until the rice is al dente and the chicken is cooked through, 7-10 additional minutes. The dish will thicken as it cools, and you can taste the flavor much better when the chicken and rice is warm vs piping hot, so I like to let the pot sit uncovered for an additional 10 minutes or so before scooping into bowls and serving. Add dried parsley and chicken stock then turn heat up to high to bring to a boil, stirring occasionally to ensure the rice doesn’t stick to the bottom of the pot as it comes to a boil.", "score": 0.9999001, "raw_content": null}, {"url": "https://cookinginthemidwest.com/blog/marry-me-chicken-rice/", "title": "Marry Me Chicken and Rice - Cooking in the Midwest", "content": "# Marry Me Chicken and Rice. One Pan Marry Me Chicken and Rice is an easy dinner recipe the whole family will love! This chicken and rice dish has all of the flavors of Marry Me Chicken, but is all made in one pan in about 30 minutes! ## Make Marry Me Chicken and Rice. Season the chicken with salt, pepper, oregano, thyme, onion powder, garlic powder, and red pepper flakes. Next, add 1 tbsp minced garlic, the chopped sun dried tomatoes, 1 cup of uncooked and rinsed long grain white rice, and 2 cups of chicken broth. ## Serve Marry Me Chicken and Rice. ## Marry Me Chicken and Rice. Marry Me Chicken and Rice is an easy one pan dinner that can be made in about 30 minutes! Keyword: Marry Me Chicken and Rice, One Pan Meal. * Next, add 1 tbsp minced garlic, the chopped sun dried tomatoes, 1 cup of uncooked and rinsed rice, and 2 cups of chicken broth.", "score": 0.99983394, "raw_content": null}, {"url": "https://www.lifeisbutadish.com/30-minute-one-pan-chicken-and-rice/", "title": "30 Minute One Pan Chicken and Rice - Life is but a Dish", "content": "Home » Main Dishes » Chicken » 30 Minute One Pan Chicken and Rice. # 30 Minute One Pan Chicken and Rice. Juicy, tender chicken, fluffy jasmine rice, sweet, caramelized onions and peppers come together for a flavor packed one pan meal. That’s why I’m so excited to share this One Pan Chicken and Rice recipe with you. This dish has everything you need: tender chicken, perfectly seasoned rice, and veggies all in one pan. Stir in the rice (yes, right in the pan with everything else!), pour in the chicken broth, and let it all simmer. So, next time you’re in a dinner rut, give this One Pan Chicken and Rice a try. ## 30 Minute One Pan Chicken and Rice. Juicy, tender chicken, fluffy jasmine rice, sweet, caramelized onions and peppers come together for a flavor packed one pan meal. ## 12 comments on “30 Minute One Pan Chicken and Rice”.", "score": 0.9997527, "raw_content": null}, {"url": "https://www.simplyrecipes.com/one-pot-chicken-and-rice-recipe-8765045", "title": "My Mom\'s One-Pot Chicken and Rice Is Pure Comfort Food", "content": "# My Mom’s One-Pot Chicken and Rice Is Pure Comfort Food. This simple dish of shredded chicken and creamy rice is like a warm hug. * One-pot chicken and rice is a cozy, homey dish — minimal fuss, maximum comfort. For me, tha ...
#               AIMessage(content=[{'type': 'text', 'text': "You can make several delicious dishes with leftover chicken and rice! Here are a few suggestions:\n\n*   Easy Chicken and Rice\n*   One-Pot Chicken and Rice\n*   Marry Me Chicken and Rice\n*   30 Minute One Pan Chicken and Rice\n*   My Mom's One-Pot Chicken and Rice\n\nWould you like the instructions for any of these recipes?", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bc77c-a7e9-70b0-a199-a51677d90837-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1413, 'output_tokens': 222, 'total_tokens': 1635, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 143}})]}
