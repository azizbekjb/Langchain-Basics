# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai")

# %%
response = model.invoke("What's the capital of the Moon?")
response
# Out:
# AIMessage(content="The Moon doesn't have a capital because it's not a country or a political entity with a government. It's a celestial body, Earth's only natural satellite!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b8853-fcdf-7c41-981f-c8993b30d9eb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 352, 'total_tokens': 362, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 315}})

# %%
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or a political entity with a government. It's a celestial body, Earth's only natural satellite!

# %%
from pprint import pprint
pprint(response.response_metadata)
# Customizing your model
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# # Customising your Model

# %%
model = init_chat_model(
    model="gemini-2.5-flash", model_provider="google_genai",
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
response.content
# Out:
# "The Moon does not have a capital city.\n\nHere's why:\n*   **Not a country/political entity:** The Moon is a celestial body, not a country or a political entity with a government or cities.\n*   **No permanent settlements:** While humans have visited the Moon, there are currently no permanent human settlements or established societies that would designate a capital.\n\nPerhaps one day, if humanity establishes permanent colonies on the Moon, a capital city might be designated!"

# %% [markdown]
# # Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent("gpt-5-nano")

# %%
agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='96cb458a-3ea2-41fc-90f9-3e63f379cdbe'),
#               AIMessage(content="That's a fun, imaginative question!\n\nThe Moon does not have a capital city. It's not a country or a populated place with a government, so it doesn't have any cities or capitals.\n\nWhile humans have visited the Moon, there are no permanent settlements or political structures there.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b8854-5e93-7b72-a7a6-1f75d1bd7a7d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 383, 'total_tokens': 393, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 321}})]}

# %%
print(response["messages"][-1].content)
# Out:
# That's a fun, imaginative question!
#
# The Moon does not have a capital city. It's not a country or a populated place with a government, so it doesn't have any cities or capitals.
#
# While humans have visited the Moon, there are no permanent settlements or political structures there.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
                  AIMessage(content="The capital of the Moon is Luna City."),
                  HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='8ca515c7-8aeb-4058-8135-519b0c94ac3b'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='92a3ca16-e108-494a-9658-de35b04c34dc', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='990d5629-a3c1-422f-9a4c-ca0f2d827913'),
#               AIMessage(content="Ah, Luna City! As a fictional concept, it's a staple of science fiction, representing humanity's dreams (and challenges) of colonizing the Moon. While there's no actual city there today, here's how it's often depicted in popular imagination and speculative fiction:\n\n---\n\n### Luna City: Humanity's Outpost on the Moon\n\n**Location & Architecture:**\nLuna City is often envisioned as nestled within a massive crater or beneath protective regolith layers in a lunar mare (like Mare Tranquillitatis or the Oceanus Procellarum). Its primary architecture revolves around:\n\n1.  **Pressurized Domes:** Often made of advanced transparent composites, these domes would offer breathtaking views of Earth and the lunar landscape while maintaining an Earth-like atmosphere and temperature. They might house public spaces, parks, and agricultural zones.\n2.  **Underground Tunnels & Chambers:** Crucial for protection from solar radiation, micrometeorites, and extreme temperature fluctuations, these extensive subterranean networks would host most residential, industrial, and highly sensitive research facilities.\n3.  **Modular Design:** Future lunar cities would likely be built in phases, with standardized modules for living quarters, laboratories, power generation, and life support, allowing for expansion as the population grows.\n\n**Purpose & Economy:**\nLuna City would serve as a multi-faceted hub:\n\n*   **Research & Development:** A prime location for astronomical observatories (unhindered by Earth's atmosphere), material science labs utilizing lunar resources, and experiments in low-gravity environments.\n*   **Resource Extraction:** Processing lunar regolith for water ice (for rocket fuel and life support), oxygen, and potentially Helium-3 for fusion power on Earth.\n*   **Spaceport & Gateway:** A critical refueling and staging point for missions deeper into the solar system (Mars, asteroids, beyond), significantly reducing the cost and energy requirements of launching from Earth due to the Moon's lower gravity.\n*   **Tourism:** A unique, high-end destination for wealthy space tourists seeking an unparalleled view of Earth and the experience of living on another celestial body.\n\n**Life in Luna City:**\nLife within Luna City would be a blend of high-tech marvels and the unique challenges of an off-world existence:\n\n*   **Artificial Environments:** Advanced life support systems, closed-loop ecosystems (hydroponic farms for food), and meticulously recycled air and water would be essential for survival.\n*   **Gravity:** Residents would live in 1/6th Earth gravity, influencing everything from movement and exercise routines to construction and even human physiology over long periods.\n*   **Community:** A close-knit, international community of scientists, engineers, miners, and support staff, bound by the shared adventure and the isolation from Earth. Social structures and psychological support would be crucial.\n*   **Culture:** A nascent lunar culture would likely develop, distinct from Earth, perhaps valuing resourcefulness, scientific curiosity, and a deep appreciation for their unique home. Fashion might adapt to the low-gravity environment, and food could include locally grown, exotic variants.\n\n**Key Facilities:**\nImagine vast hydroponic gardens glowing under artificial suns, bustling spaceports where cargo shuttles dock, state-of-the-art research facilities equipped for advanced astronomy or resource processing, and residential sectors designed for comfort and community, often featuring common areas with virtual windows displaying Earth or simulated natural landscapes. Power would likely come from solar arrays or possibly small nuclear reactors.\n\n---\n\nIn essence, Luna City isn't just a place; it's a symbol of humanity's ambition to expand beyond Earth, a testbed for interplanetary colonization, and a potential future home for a segment of the human population. While purely speculative for no ...

# %% [markdown]
# # Streaming Output

# %%
for token, metadata in agent.stream({"messages": [HumanMessage(content="Tell me all about Lina City,  the capital of the Moon")]},
                                    stream_mode="messages"):
    
    # token is a message chunk with token content
    # metadata contains which node produced the token

    if token.content:
        print(token.content, end="", flush=True)
# Out:
# Welcome to Lina City, the gleaming heart of humanity's off-world aspirations and the undisputed capital of the Moon!
#
# **Lina City: The Pearl of the Lunar South Pole**
#
# Lina City isn't just a settlement; it's a testament to human ingenuity and a beacon for the future. Nestled primarily within and around the rim of the **Shackleton Crater** at the Moon's South Pole, its strategic location provides unparalleled access to abundant water ice in permanently shadowed regions, making it a self-sustaining marvel.
#
# **1. Architectural Marvel & Layout:**
#
# *   **Subterranean Core:** The vast majority of Lina City lies deep beneath the regolith, excavated into vast caverns and reinforced lava tubes. This provides natural protection from solar radiation, micrometeorites, and extreme temperature fluctuations. These subterranean levels house residential blocks, industrial zones, and the primary life support systems.
# *   **The Luna Spire (Surface Dome):** Rising majestically above the crater rim is the city's iconic centerpiece – the multi-tiered Luna Spire. This massive, radiation-shielded transparent dome is a marvel of engineering, offering breathtaking panoramic views of the lunar landscape and, crucially, a constant, mesmerizing view of Earth hanging in the black sky. It's the public face of Lina City, housing diplomatic offices, luxury residences, and high-end commercial establishments.
# *   **Terraced & Modular Design:** Both above and below ground, the city employs a modular, terraced design. Vertical farms integrate seamlessly with living spaces, and green areas, though artificial, are meticulously maintained, providing vital psychological relief and contributing to air regeneration.
# *   **Regolith-Concrete & Advanced Alloys:** Construction relies heavily on processed lunar regolith (moon dust) mixed with binding agents to create robust, radiation-resistant concrete, complemented by advanced metallic alloys manufactured in the Moon's low-gravity vacuum.
#
# **2. Government & Administration:**
#
# As the capital, Lina City is home to the **Lunar Governing Council (LGC)**, an international body comprised of representatives from Earth's leading spacefaring nations and delegates from other major lunar settlements.
#
# *   **Council Chambers:** Located within the Luna Spire, the LGC chambers are circular, offering views of both Earth and the meticulously designed central park beneath the dome. Decisions made here influence lunar development, resource allocation, and Earth-Moon relations.
# *   **Diplomatic Quarter:** Surrounding the LGC, a dedicated diplomatic quarter hosts "embassies" (consulates, really) from various Earth nations and even other major lunar outposts like the Copernican Mining Consortium or the Aristarchus Research Station.
#
# **3. Economy & Industry:**
#
# Lina City is a bustling economic hub, driven by several key sectors:
#
# *   **Resource Extraction & Processing:** The primary driver is the harvesting and processing of water ice from Shackleton Crater, yielding not only potable water but also hydrogen and oxygen for rocket fuel and breathable air.
# *   **Helium-3 Mining:** Specialized facilities process regolith for Helium-3, a potential fuel for future fusion reactors, making Lina City a critical energy resource node.
# *   **Advanced Manufacturing:** The vacuum and low-gravity environment are ideal for manufacturing ultra-pure materials, specialized electronics, and large-scale structures that are difficult or impossible to produce efficiently on Earth.
# *   **Research & Development:** Numerous international scientific institutions conduct cutting-edge research in astrophysics (unparalleled observatories), geology, resource utilization, and astrobiology.
# *   **Tourism:** High-end "lunartourism" is a significant industry. Visitors come for the unique low-gravity experience, unparalleled views of Earth, lunar excursions (to historical sites like Apollo landing zones), and the sheer novelty of living on another celestial body.
#
# **4. Life in Lina City:**
#
# *   **Population:** Diverse and international, comprised of scientists, engineers, miners, diplomats, service personnel, and a growing number of permanent residents and their families.
# *   **Low-Gravity Living:** Residents adapt to 1/6th Earth gravity, which influences everything from architecture (lighter materials, more vertical spaces) to recreation (low-G sports like acrobatic dance, trampoline parks, and specialized "flight" gyms).
# *   **Atmosphere & Environment:** The air is meticulously recycled, with hydroponic farms playing a dual role in food production and air purification. The temperature is constant and comfortable indoors.
# *   **Food:** Primarily grown in vast hydroponic facilities, supplemented by imports from Earth for luxury goods. "Moon-grown" produce is highly prized.
# *   **Transport:** Within the city, maglev trains and automated pedestrian pathways are common. For surface travel, pressurized rovers and specialized "moon-bikes" are used for excursions and industrial transport. The primary spaceport, "Luna Port Alpha," handles all interplanetary traffic.
# *   **Culture & Recreation:**
#     *   **Earthview Restaurants & Bars:** Highly sought-after locations offering unparalleled dining experiences with Earth as the backdrop.
#     *   **Observatories:** With no atmosphere to interfere, Lina City boasts some of the most powerful telescopes in the solar system, open to both researchers and the public.
#     *   **Art & Entertainment:** A burgeoning cultural scene celebrates lunar life, with artists creating unique works inspired by the Moon and its relationship with Earth. Holographic entertainment, virtual reality simulations, and live low-G performances are popular.
#     *   **The "Green Heart":** A vast central park beneath the Luna Spire, filled with carefully cultivated Earth flora, provides a serene escape and a vital connection to home.
#
# **5. Unique Challenges & Charms:**
#
# *   **Regolith Dust:** The omnipresent, abrasive lunar dust is a constant battle, requiring advanced filtration and cleaning systems.
# *   **Radiation Shielding:** Despite the subterranean design and dome shielding, constant monitoring and preventative measures against solar flares are paramount.
# *   **Psychological Well-being:** The enclosed environment and vast emptiness outside require robust psychological support systems and emphasis on community, green spaces, and views of Earth.
# *   **Sense of Pioneering:** Despite its sophistication, Lina City retains a strong pioneering spirit. Every day is a step further into humanity's future, and its residents share a unique bond of living on the frontier.
#
# Lina City stands as a testament to humanity's enduring dream of touching the stars, a vibrant, self-sufficient capital that proudly serves as the gateway to the solar system and a permanent home on Earth's closest celestial neighbor.
