# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai")

# %%
response = model.invoke("What's the capital of the Moon?")
response
# Out:
# AIMessage(content="The Moon does not have a capital. It's a celestial body, not a country, and therefore doesn't have cities, a government, or a political structure.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b87d7-d2d5-7ba1-8266-3ebb3265b684-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 356, 'total_tokens': 366, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 321}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital. It's a celestial body, not a country, and therefore doesn't have cities, a government, or a political structure.

# %%
from pprint import pprint
pprint(response.response_metadata)
# Customizing your model
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# # Customising your Model

# %%
model = init_chat_model(
    model="gemini-2.5-flash", model_provider="google_genai",
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
response.content
# Out:
# "That's a fun question!\n\nThe Moon doesn't actually have a capital, because it's a celestial body and not a country. It doesn't have a government, cities, or permanent human inhabitants to establish a capital.\n\nIf it *did* have one, though, many might argue it should be **Tranquility Base**, the site where Apollo 11 landed and Neil Armstrong took his first steps on the Moon!"

# %% [markdown]
# # Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent("gpt-5-nano")

# %%
agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='4471c7c3-0088-4f7c-a3e2-63069d508be1'),
#               AIMessage(content='That\'s a fun question!\n\nThe Moon does **not** have a capital city. Here\'s why:\n\n1.  **Not a country:** The Moon is a celestial body, not a sovereign nation or political entity.\n2.  **No government:** There\'s no governing body, human or otherwise, that administers the Moon.\n3.  **No permanent settlements:** While humans have visited the Moon, there are no permanent cities or towns established there... yet!\n\nIf humanity ever colonizes the Moon extensively, we would likely establish settlements, and one of them might eventually be designated as a "capital" for a lunar government or territory. But for now, it\'s just a beautiful, airless orb without any official cities.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b87e0-bf5e-70d2-b44c-065d26312281-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 810, 'total_tokens': 820, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 655}})]}
